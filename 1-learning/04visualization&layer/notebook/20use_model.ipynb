# %% [markdown]
# ## 用训练好的caffemodel来进行分类

# %% [markdown]
# caffe程序自带有一张小猫图片，存放路径为caffe根目录下的 examples/images/cat.jpg, 如果我们想用一个训练好的caffemodel来对这张图片进行分类，那该怎么办呢？ 如果不用这张小猫图片，换一张别的图片，又该怎么办呢？如果学会了小猫图片的分类，那么换成其它图片，程序实际上是一样的。
#
# 开发caffe的贾大牛团队，利用imagenet图片和caffenet模型训练好了一个caffemodel,  供大家下载。要进行图片的分类，这个caffemodel是最好不过的了。所以，不管是用c++来进行分类，还是用python接口来分类，我们都应该准备这样三个文件：
#
# 1、caffemodel文件。
#
#   可以直接在浏览器里输入地址下载，也可以运行脚本文件下载。下载地址为：http://dl.caffe.berkeleyvision.org/bvlc_reference_caffenet.caffemodel
#
# 文件名称为：bvlc_reference_caffenet.caffemodel，文件大小为230M左右，为了代码的统一，将这个caffemodel文件下载到caffe根目录下的 models/bvlc_reference_caffenet/ 文件夹下面。也可以运行脚本文件进行下载：

# %%
! pwd
# Out:
# /home/yeler082/caffe

# %%
import sys,os,caffe
#设置当前目录
caffe_root = '/home/yeler082/caffe/' 
# sys.path.insert(0, caffe_root + 'python')
os.chdir(caffe_root)

# %%
! pwd
# Out:
# /home/yeler082/caffe

# %%
! ./scripts/download_model_binary.py models/bvlc_reference_caffenet
# Out:
# Model already exists.

# %% [markdown]
# 2、均值文件。
#
# 有了caffemodel文件，就需要对应的均值文件，在测试阶段，需要把测试数据减去均值。这个文件我们用脚本来下载，在caffe根目录下执行：

# %%
! sh ./data/ilsvrc12/get_ilsvrc_aux.sh
# Out:
# Downloading...
# --2018-10-20 09:33:13--  http://dl.caffe.berkeleyvision.org/caffe_ilsvrc12.tar.gz
# Resolving dl.caffe.berkeleyvision.org (dl.caffe.berkeleyvision.org)... 169.229.222.251
# Connecting to dl.caffe.berkeleyvision.org (dl.caffe.berkeleyvision.org)|169.229.222.251|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: http://202.117.4.101/cache/6/02/dl.caffe.berkeleyvision.org/7dc6c6cb703abfdad189a236c0d3d32e/caffe_ilsvrc12.tar.gz [following]
# --2018-10-20 09:33:13--  http://202.117.4.101/cache/6/02/dl.caffe.berkeleyvision.org/7dc6c6cb703abfdad189a236c0d3d32e/caffe_ilsvrc12.tar.gz
# Connecting to 202.117.4.101:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 17858008 (17M) [application/octet-stream]
# Saving to: ‘caffe_ilsvrc12.tar.gz’
#
# caffe_ilsvrc12.tar. 100%[===================>]  17.03M  88.7MB/s    in 0.2s
#
# 2018-10-20 09:33:13 (88.7 MB/s) - ‘caffe_ilsvrc12.tar.gz’ saved [17858008/17858008]
#
# Unzipping...
# Done.

# %% [markdown]
# 执行并下载后，均值文件放在 data/ilsvrc12/ 文件夹里。
#
# 3、synset_words.txt文件
#
# 在调用脚本文件下载均值的时候，这个文件也一并下载好了。里面放的是1000个类的名称。
#
# 数据准备好了，我们就可以开始分类了，我们给大家提供两个版本的分类方法：
#
# ### 一、c++方法
#
# 在caffe根目录下的 examples/cpp-classification/ 文件夹下面，有个classification.cpp文件，就是用来分类的。当然编译后，放在/build/examples/cpp_classification/ 下面
#
# 我们就直接运行命令：

# %%
! ./build/examples/cpp_classification/classification.bin \
  models/bvlc_reference_caffenet/deploy.prototxt \
  models/bvlc_reference_caffenet/bvlc_reference_caffenet.caffemodel \
  data/ilsvrc12/imagenet_mean.binaryproto \
  data/ilsvrc12/synset_words.txt \
  examples/images/cat.jpg
# Out:
# ---------- Prediction for examples/images/cat.jpg ----------
# 0.3134 - "n02123045 tabby, tabby cat"
# 0.2380 - "n02123159 tiger cat"
# 0.1235 - "n02124075 Egyptian cat"
# 0.1003 - "n02119022 red fox, Vulpes vulpes"
# 0.0715 - "n02127052 lynx, catamount"

# %% [markdown]
# 命令很长，用了很多的\符号来换行。可以看出，从第二行开始就是参数，每行一个，共需要4个参数
#
# 运行成功后，输出top-5结果：
# 即有0.3134的概率为tabby cat, 有0.2380的概率为tiger cat ......

# %% [markdown]
# ### 二、python方法
#
# python接口可以使用jupyter notebook来进行可视化操作，因此推荐使用这种方法。
#
# 在这里我就不用可视化了，编写一个py文件，命名为py_classify.py

# %%
#coding=utf-8
#加载必要的库
import numpy as np
import sys,os

#设置当前目录
caffe_root = '/home/yeler082/caffe/' 
sys.path.insert(0, caffe_root + 'python')
import caffe
os.chdir(caffe_root)

net_file=caffe_root + 'models/bvlc_reference_caffenet/deploy.prototxt'
caffe_model=caffe_root + 'models/bvlc_reference_caffenet/bvlc_reference_caffenet.caffemodel'
mean_file=caffe_root + 'python/caffe/imagenet/ilsvrc_2012_mean.npy'

net = caffe.Net(net_file,caffe_model,caffe.TEST)
transformer = caffe.io.Transformer({'data': net.blobs['data'].data.shape})
transformer.set_transpose('data', (2,0,1))
transformer.set_mean('data', np.load(mean_file).mean(1).mean(1))
transformer.set_raw_scale('data', 255) 
transformer.set_channel_swap('data', (2,1,0))

im=caffe.io.load_image(caffe_root+'examples/images/cat.jpg')
net.blobs['data'].data[...] = transformer.preprocess('data',im)
out = net.forward()


imagenet_labels_filename = caffe_root + 'data/ilsvrc12/synset_words.txt'
labels = np.loadtxt(imagenet_labels_filename, str, delimiter='\t')

top_k = net.blobs['prob'].data[0].flatten().argsort()[-1:-6:-1]
for i in np.arange(top_k.size):
    print top_k[i], labels[top_k[i]]
# Out:
# 281 n02123045 tabby, tabby cat
# 282 n02123159 tiger cat
# 285 n02124075 Egyptian cat
# 277 n02119022 red fox, Vulpes vulpes
# 287 n02127052 lynx, catamount

# %% [markdown]
# caffe开发团队实际上也编写了一个python版本的分类文件，路径为 python/classify.py
#
# 运行这个文件必需两个参数，一个输入图片文件，一个输出结果文件。而且运行必须在python目录下。假设当前目录是caffe根目录，则运行：

# %%
os.chdir(caffe_root+'/python')
! python2 classify.py ../examples/images/cat.jpg result.npy
# Out:
# CPU mode
# WARNING: Logging before InitGoogleLogging() is written to STDERR
# I1020 09:40:32.330868  6533 net.cpp:51] Initializing net from parameters:
# name: "CaffeNet"
# state {
#   phase: TEST
#   level: 0
# }
# layer {
#   name: "data"
#   type: "Input"
#   top: "data"
#   input_param {
#     shape {
#       dim: 10
#       dim: 3
#       dim: 227
#       dim: 227
#     }
#   }
# }
# layer {
#   name: "conv1"
#   type: "Convolution"
#   bottom: "data"
#   top: "conv1"
#   convolution_param {
#     num_output: 96
#     kernel_size: 11
#     stride: 4
#   }
# }
# layer {
#   name: "relu1"
#   type: "ReLU"
#   bottom: "conv1"
#   top: "conv1"
# }
# layer {
#   name: "pool1"
#   type: "Pooling"
#   bottom: "conv1"
#   top: "pool1"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "norm1"
#   type: "LRN"
#   bottom: "pool1"
#   top: "norm1"
#   lrn_param {
#     local_size: 5
#     alpha: 0.0001
#     beta: 0.75
#   }
# }
# layer {
#   name: "conv2"
#   type: "Convolution"
#   bottom: "norm1"
#   top: "conv2"
#   convolution_param {
#     num_output: 256
#     pad: 2
#     kernel_size: 5
#     group: 2
#   }
# }
# layer {
#   name: "relu2"
#   type: "ReLU"
#   bottom: "conv2"
#   top: "conv2"
# }
# layer {
#   name: "pool2"
#   type: "Pooling"
#   bottom: "conv2"
#   top: "pool2"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "norm2"
#   type: "LRN"
#   bottom: "pool2"
#   top: "norm2"
#   lrn_param {
#     local_size: 5
#     alpha: 0.0001
#     beta: 0.75
#   }
# }
# layer {
#   name: "conv3"
#   type: "Convolution"
#   bottom: "norm2"
#   top: "conv3"
#   convolution_param {
#     num_output: 384
#     pad: 1
#     kernel_size: 3
#   }
# }
# layer {
#   name: "relu3"
#   type: "ReLU"
#   bottom: "conv3"
#   top: "conv3"
# }
# layer {
#   name: "conv4"
#   type: "Convolution"
#   bottom: "conv3"
#   top: "conv4"
#   convolution_param {
#     num_output: 384
#     pad: 1
#     kernel_size: 3
#     group: 2
#   }
# }
# layer {
#   name: "relu4"
#   type: "ReLU"
#   bottom: "conv4"
#   top: "conv4"
# }
# layer {
#   name: "conv5"
#   type: "Convolution"
#   bottom: "conv4"
#   top: "conv5"
#   convolution_param {
#     num_output: 256
#     pad: 1
#     kernel_size: 3
#     group: 2
#   }
# }
# layer {
#   name: "relu5"
#   type: "ReLU"
#   bottom: "conv5"
#   top: "conv5"
# }
# layer {
#   name: "pool5"
#   type: "Pooling"
#   bottom: "conv5"
#   top: "pool5"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "fc6"
#   type: "InnerProduct"
#   bottom: "pool5"
#   top: "fc6"
#   inner_product_param {
#     num_output: 4096
#   }
# }
# layer {
#   name: "relu6"
#   type: "ReLU"
#   bottom: "fc6"
#   top: "fc6"
# }
# layer {
#   name: "drop6"
#   type: "Dropout"
#   bottom: "fc6"
#   top: "fc6"
#   dropout_param {
#     dropout_ratio: 0.5
#   }
# }
# layer {
#   name: "fc7"
#   type: "InnerProduct"
#   bottom: "fc6"
#   top: "fc7"
#   inner_product_param {
#     num_output: 4096
#   }
# }
# layer {
#   name: "relu7"
#   type: "ReLU"
#   bottom: "fc7"
#   top: "fc7"
# }
# layer {
#   name: "drop7"
#   type: "Dropout"
#   bottom: "fc7"
#   top: "fc7"
#   dropout_param {
#     dropout_ratio: 0.5
#   }
# }
# layer {
#   name: "fc8"
#   type: "InnerProduct"
#   bottom: "fc7"
#   top: "fc8"
#   inner_product_param {
#     num_output: 1000
#   }
# }
# layer {
#   name: "prob"
#   type: "Softmax"
#   bottom: "fc8"
#   top: "prob"
# }
# I1020 09:40:32.331073  6533 layer_factory.hpp:77] Creating layer data
# I1020 09:40:32.331084  6533 net.cpp:84] Creating Layer data
# I1020 09:40:32.331090  6533 net.cpp:380] data -> data
# I1020 09:40:32.331105  6533 net.cpp:122] Setting up data
# I1020 09:40:32.331113  6533 net.cpp:129] Top shape: 10 3 227 227 (1545870)
# I1020 09:40:32.331117  6533 net.cpp:137] Memory required for data: 6183480
# I1020 09:40:32.331122  6533 layer_factory.hpp:77] Creating layer conv1
# I1020 09:40:32.331130  6533 net.cpp:84] Creating Layer conv1
# I1020 09:40:32.331135  6533 net.cpp:406] conv1 <- data
# I1020 09:40:32.331140  6533 net.cpp:380] conv1 -> conv1
# I1020 09:40:32.937336  6533 net.cpp:122] Setting up conv1
# I1020 09:40:32.937374  6533 net.cpp:129] Top shape: 10 96 55 55 (2904000)
# I1020 09:40:32.937379  6533 net.cpp:137] Memory required for data: 17799480
# I1020 09:40:32.937397  6533 layer_factory.hpp:77] Creating layer relu1
# I1020 09:40:32.937412  6533 net.cpp:84] Creating Layer relu1
# I1020 09:40:32.937415  6533 net.cpp:406] relu1 <- conv1
# I1020 09:40:32.937424  6533 net.cpp:367] relu1 -> conv1 (in-place)
# I1020 09:40:32.937835  6533 net.cpp:122] Setting up relu1
# I1020 09:40:32.937845  6533 net.cpp:129] Top shape: 10 96 55 55 (2904000)
# I1020 09:40:32.937849  6533 net.cpp:137] Memory required for data: 29415480
# I1020 09:40:32.937853  6533 layer_factory.hpp:77] Creating layer pool1
# I1020 09:40:32.937863  6533 net.cpp:84] Creating Layer pool1
# I1020 09:40:32.937867  6533 net.cpp:406] pool1 <- conv1
# I1020 09:40:32.937872  6533 net.cpp:380] pool1 -> pool1
# I1020 09:40:32.937885  6533 net.cpp:122] Setting up pool1
# I1020 09:40:32.937889  6533 net.cpp:129] Top shape: 10 96 27 27 (699840)
# I1020 09:40:32.937892  6533 net.cpp:137] Memory required for data: 32214840
# I1020 09:40:32.937896  6533 layer_factory.hpp:77] Creating layer norm1
# I1020 09:40:32.937913  6533 net.cpp:84] Creating Layer norm1
# I1020 09:40:32.937917  6533 net.cpp:406] norm1 <- pool1
# I1020 09:40:32.937923  6533 net.cpp:380] norm1 -> norm1
# I1020 09:40:32.938321  6533 net.cpp:122] Setting up norm1
# I1020 09:40:32.938333  6533 net.cpp:129] Top shape: 10 96 27 27 (699840)
# I1020 09:40:32.938336  6533 net.cpp:137] Memory required for data: 35014200
# I1020 09:40:32.938340  6533 layer_factory.hpp:77] Creating layer conv2
# I1020 09:40:32.938351  6533 net.cpp:84] Creating Layer conv2
# I1020 09:40:32.938355  6533 net.cpp:406] conv2 <- norm1
# I1020 09:40:32.938362  6533 net.cpp:380] conv2 -> conv2
# I1020 09:40:32.941975  6533 net.cpp:122] Setting up conv2
# I1020 09:40:32.941989  6533 net.cpp:129] Top shape: 10 256 27 27 (1866240)
# I1020 09:40:32.942009  6533 net.cpp:137] Memory required for data: 42479160
# I1020 09:40:32.942020  6533 layer_factory.hpp:77] Creating layer relu2
# I1020 09:40:32.942028  6533 net.cpp:84] Creating Layer relu2
# I1020 09:40:32.942031  6533 net.cpp:406] relu2 <- conv2
# I1020 09:40:32.942036  6533 net.cpp:367] relu2 -> conv2 (in-place)
# I1020 09:40:32.942764  6533 net.cpp:122] Setting up relu2
# I1020 09:40:32.942777  6533 net.cpp:129] Top shape: 10 256 27 27 (1866240)
# I1020 09:40:32.942782  6533 net.cpp:137] Memory required for data: 49944120
# I1020 09:40:32.942802  6533 layer_factory.hpp:77] Creating layer pool2
# I1020 09:40:32.942809  6533 net.cpp:84] Creating Layer pool2
# I1020 09:40:32.942813  6533 net.cpp:406] pool2 <- conv2
# I1020 09:40:32.942821  6533 net.cpp:380] pool2 -> pool2
# I1020 09:40:32.942831  6533 net.cpp:122] Setting up pool2
# I1020 09:40:32.942836  6533 net.cpp:129] Top shape: 10 256 13 13 (432640)
# I1020 09:40:32.942838  6533 net.cpp:137] Memory required for data: 51674680
# I1020 09:40:32.942842  6533 layer_factory.hpp:77] Creating layer norm2
# I1020 09:40:32.942852  6533 net.cpp:84] Creating Layer norm2
# I1020 09:40:32.942855  6533 net.cpp:406] norm2 <- pool2
# I1020 09:40:32.942860  6533 net.cpp:380] norm2 -> norm2
# I1020 09:40:32.943279  6533 net.cpp:122] Setting up norm2
# I1020 09:40:32.943289  6533 net.cpp:129] Top shape: 10 256 13 13 (432640)
# I1020 09:40:32.943292  6533 net.cpp:137] Memory required for data: 53405240
# I1020 09:40:32.943296  6533 layer_factory.hpp:77] Creating layer conv3
# I1020 09:40:32.943305  6533 net.cpp:84] Creating Layer conv3
# I1020 09:40:32.943310  6533 net.cpp:406] conv3 <- norm2
# I1020 09:40:32.943317  6533 net.cpp:380] conv3 -> conv3
# I1020 09:40:32.947036  6533 net.cpp:122] Setting up conv3
# I1020 09:40:32.947048  6533 net.cpp:129] Top shape: 10 384 13 13 (648960)
# I1020 09:40:32.947053  6533 net.cpp:137] Memory required for data: 56001080
# I1020 09:40:32.947080  6533 layer_factory.hpp:77] Creating layer relu3
# I1020 09:40:32.947088  6533 net.cpp:84] Creating Layer relu3
# I1020 09:40:32.947090  6533 net.cpp:406] relu3 <- conv3
# I1020 09:40:32.947096  6533 net.cpp:367] relu3 -> conv3 (in-place)
# I1020 09:40:32.947505  6533 net.cpp:122] Setting up relu3
# I1020 09:40:32.947517  6533 net.cpp:129] Top shape: 10 384 13 13 (648960)
# I1020 09:40:32.947521  6533 net.cpp:137] Memory required for data: 58596920
# I1020 09:40:32.947526  6533 layer_factory.hpp:77] Creating layer conv4
# I1020 09:40:32.947535  6533 net.cpp:84] Creating Layer conv4
# I1020 09:40:32.947540  6533 net.cpp:406] conv4 <- conv3
# I1020 09:40:32.947544  6533 net.cpp:380] conv4 -> conv4
# I1020 09:40:32.952467  6533 net.cpp:122] Setting up conv4
# I1020 09:40:32.952482  6533 net.cpp:129] Top shape: 10 384 13 13 (648960)
# I1020 09:40:32.952487  6533 net.cpp:137] Memory required for data: 61192760
# I1020 09:40:32.952494  6533 layer_factory.hpp:77] Creating layer relu4
# I1020 09:40:32.952502  6533 net.cpp:84] Creating Layer relu4
# I1020 09:40:32.952505  6533 net.cpp:406] relu4 <- conv4
# I1020 09:40:32.952512  6533 net.cpp:367] relu4 -> conv4 (in-place)
# I1020 09:40:32.953363  6533 net.cpp:122] Setting up relu4
# I1020 09:40:32.953377  6533 net.cpp:129] Top shape: 10 384 13 13 (648960)
# I1020 09:40:32.953380  6533 net.cpp:137] Memory required for data: 63788600
# I1020 09:40:32.953400  6533 layer_factory.hpp:77] Creating layer conv5
# I1020 09:40:32.953410  6533 net.cpp:84] Creating Layer conv5
# I1020 09:40:32.953415  6533 net.cpp:406] conv5 <- conv4
# I1020 09:40:32.953421  6533 net.cpp:380] conv5 -> conv5
# I1020 09:40:32.957916  6533 net.cpp:122] Setting up conv5
# I1020 09:40:32.957929  6533 net.cpp:129] Top shape: 10 256 13 13 (432640)
# I1020 09:40:32.957934  6533 net.cpp:137] Memory required for data: 65519160
# I1020 09:40:32.957947  6533 layer_factory.hpp:77] Creating layer relu5
# I1020 09:40:32.957953  6533 net.cpp:84] Creating Layer relu5
# I1020 09:40:32.957957  6533 net.cpp:406] relu5 <- conv5
# I1020 09:40:32.957964  6533 net.cpp:367] relu5 -> conv5 (in-place)
# I1020 09:40:32.958374  6533 net.cpp:122] Setting up relu5
# I1020 09:40:32.958384  6533 net.cpp:129] Top shape: 10 256 13 13 (432640)
# I1020 09:40:32.958387  6533 net.cpp:137] Memory required for data: 67249720
# I1020 09:40:32.958391  6533 layer_factory.hpp:77] Creating layer pool5
# I1020 09:40:32.958398  6533 net.cpp:84] Creating Layer pool5
# I1020 09:40:32.958402  6533 net.cpp:406] pool5 <- conv5
# I1020 09:40:32.958410  6533 net.cpp:380] pool5 -> pool5
# I1020 09:40:32.958418  6533 net.cpp:122] Setting up pool5
# I1020 09:40:32.958423  6533 net.cpp:129] Top shape: 10 256 6 6 (92160)
# I1020 09:40:32.958426  6533 net.cpp:137] Memory required for data: 67618360
# I1020 09:40:32.958429  6533 layer_factory.hpp:77] Creating layer fc6
# I1020 09:40:32.958439  6533 net.cpp:84] Creating Layer fc6
# I1020 09:40:32.958443  6533 net.cpp:406] fc6 <- pool5
# I1020 09:40:32.958448  6533 net.cpp:380] fc6 -> fc6
# I1020 09:40:33.043706  6533 net.cpp:122] Setting up fc6
# I1020 09:40:33.043758  6533 net.cpp:129] Top shape: 10 4096 (40960)
# I1020 09:40:33.043762  6533 net.cpp:137] Memory required for data: 67782200
# I1020 09:40:33.043773  6533 layer_factory.hpp:77] Creating layer relu6
# I1020 09:40:33.043800  6533 net.cpp:84] Creating Layer relu6
# I1020 09:40:33.043805  6533 net.cpp:406] relu6 <- fc6
# I1020 09:40:33.043815  6533 net.cpp:367] relu6 -> fc6 (in-place)
# I1020 09:40:33.044422  6533 net.cpp:122] Setting up relu6
# I1020 09:40:33.044432  6533 net.cpp:129] Top shape: 10 4096 (40960)
# I1020 09:40:33.044450  6533 net.cpp:137] Memory required for data: 67946040
# I1020 09:40:33.044453  6533 layer_factory.hpp:77] Creating layer drop6
# I1020 09:40:33.044461  6533 net.cpp:84] Creating Layer drop6
# I1020 09:40:33.044463  6533 net.cpp:406] drop6 <- fc6
# I1020 09:40:33.044471  6533 net.cpp:367] drop6 -> fc6 (in-place)
# I1020 09:40:33.044494  6533 net.cpp:122] Setting up drop6
# I1020 09:40:33.044515  6533 net.cpp:129] Top shape: 10 4096 (40960)
# I1020 09:40:33.044519  6533 net.cpp:137] Memory required for data: 68109880
# I1020 09:40:33.044523  6533 layer_factory.hpp:77] Creating layer fc7
# I1020 09:40:33.044531  6533 net.cpp:84] Creating Layer fc7
# I1020 09:40:33.044535  6533 net.cpp:406] fc7 <- fc6
# I1020 09:40:33.044541  6533 net.cpp:380] fc7 -> fc7
# I1020 09:40:33.082381  6533 net.cpp:122] Setting up fc7
# I1020 09:40:33.082412  6533 net.cpp:129] Top shape: 10 4096 (40960)
# I1020 09:40:33.082414  6533 net.cpp:137] Memory required for data: 68273720
# I1020 09:40:33.082424  6533 layer_factory.hpp:77] Creating layer relu7
# I1020 09:40:33.082435  6533 net.cpp:84] Creating Layer relu7
# I1020 09:40:33.082458  6533 net.cpp:406] relu7 <- fc7
# I1020 09:40:33.082466  6533 net.cpp:367] relu7 -> fc7 (in-place)
# I1020 09:40:33.083046  6533 net.cpp:122] Setting up relu7
# I1020 09:40:33.083057  6533 net.cpp:129] Top shape: 10 4096 (40960)
# I1020 09:40:33.083076  6533 net.cpp:137] Memory required for data: 68437560
# I1020 09:40:33.083081  6533 layer_factory.hpp:77] Creating layer drop7
# I1020 09:40:33.083086  6533 net.cpp:84] Creating Layer drop7
# I1020 09:40:33.083106  6533 net.cpp:406] drop7 <- fc7
# I1020 09:40:33.083128  6533 net.cpp:367] drop7 -> fc7 (in-place)
# I1020 09:40:33.083135  6533 net.cpp:122] Setting up drop7
# I1020 09:40:33.083140  6533 net.cpp:129] Top shape: 10 4096 (40960)
# I1020 09:40:33.083143  6533 net.cpp:137] Memory required for data: 68601400
# I1020 09:40:33.083148  6533 layer_factory.hpp:77] Creating layer fc8
# I1020 09:40:33.083153  6533 net.cpp:84] Creating Layer fc8
# I1020 09:40:33.083158  6533 net.cpp:406] fc8 <- fc7
# I1020 09:40:33.083163  6533 net.cpp:380] fc8 -> fc8
# I1020 09:40:33.092201  6533 net.cpp:122] Setting up fc8
# I1020 09:40:33.092213  6533 net.cpp:129] Top shape: 10 1000 (10000)
# I1020 09:40:33.092217  6533 net.cpp:137] Memory required for data: 68641400
# I1020 09:40:33.092242  6533 layer_factory.hpp:77] Creating layer prob
# I1020 09:40:33.092265  6533 net.cpp:84] Creating Layer prob
# I1020 09:40:33.092270  6533 net.cpp:406] prob <- fc8
# I1020 09:40:33.092275  6533 net.cpp:380] prob -> prob
# I1020 09:40:33.093305  6533 net.cpp:122] Setting up prob
# I1020 09:40:33.093318  6533 net.cpp:129] Top shape: 10 1000 (10000)
# I1020 09:40:33.093336  6533 net.cpp:137] Memory required for data: 68681400
# I1020 09:40:33.093340  6533 net.cpp:200] prob does not need backward computation.
# I1020 09:40:33.093345  6533 net.cpp:200] fc8 does not need backward computation.
# I1020 09:40:33.093348  6533 net.cpp:200] drop7 does not need backward computation.
# I1020 09:40:33.093353  6533 net.cpp:200] relu7 does not need backward computation.
# I1020 09:40:33.093355  6533 net.cpp:200] fc7 does not need backward computation.
# I1020 09:40:33.093375  6533 net.cpp:200] drop6 does not need backward computation.
# I1020 09:40:33.093379  6533 net.cpp:200] relu6 does not need backward computation.
# I1020 09:40:33.093397  6533 net.cpp:200] fc6 does not need backward computation.
# I1020 09:40:33.093405  6533 net.cpp:200] pool5 does not need backward computation.
# I1020 09:40:33.093410  6533 net.cpp:200] relu5 does not need backward computation.
# I1020 09:40:33.093415  6533 net.cpp:200] conv5 does not need backward computation.
# I1020 09:40:33.093420  6533 net.cpp:200] relu4 does not need backward computation.
# I1020 09:40:33.093423  6533 net.cpp:200] conv4 does not need backward computation.
# I1020 09:40:33.093428  6533 net.cpp:200] relu3 does not need backward computation.
# I1020 09:40:33.093433  6533 net.cpp:200] conv3 does not need backward computation.
# I1020 09:40:33.093438  6533 net.cpp:200] norm2 does not need backward computation.
# I1020 09:40:33.093442  6533 net.cpp:200] pool2 does not need backward computation.
# I1020 09:40:33.093447  6533 net.cpp:200] relu2 does not need backward computation.
# I1020 09:40:33.093451  6533 net.cpp:200] conv2 does not need backward computation.
# I1020 09:40:33.093456  6533 net.cpp:200] norm1 does not need backward computation.
# I1020 09:40:33.093461  6533 net.cpp:200] pool1 does not need backward computation.
# I1020 09:40:33.093464  6533 net.cpp:200] relu1 does not need backward computation.
# I1020 09:40:33.093468  6533 net.cpp:200] conv1 does not need backward computation.
# I1020 09:40:33.093472  6533 net.cpp:200] data does not need backward computation.
# I1020 09:40:33.093477  6533 net.cpp:242] This network produces output prob
# I1020 09:40:33.093493  6533 net.cpp:255] Network initialization done.
# I1020 09:40:33.287228  6533 upgrade_proto.cpp:46] Attempting to upgrade input file specified using deprecated transformation parameters: ../models/bvlc_reference_caffenet/bvlc_reference_caffenet.caffemodel
# I1020 09:40:33.287261  6533 upgrade_proto.cpp:49] Successfully upgraded file specified using deprecated data transformation parameters.
# W1020 09:40:33.287264  6533 upgrade_proto.cpp:51] Note that future Caffe releases will only support transform_param messages for transformation fields.
# I1020 09:40:33.287268  6533 upgrade_proto.cpp:55] Attempting to upgrade input file specified using deprecated V1LayerParameter: ../models/bvlc_reference_caffenet/bvlc_reference_caffenet.caffemodel
# I1020 09:40:33.588443  6533 upgrade_proto.cpp:63] Successfully upgraded file specified using deprecated V1LayerParameter
# I1020 09:40:33.637914  6533 net.cpp:744] Ignoring source layer loss
# Loading file: ../examples/images/cat.jpg
# Classifying 1 inputs.
# Done in 1.17 s.
# Saving results into result.npy
